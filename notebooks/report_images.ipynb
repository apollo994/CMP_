# %%
import pandas as pd
import numpy as np

from CMP_functions.preprocessing import *

from IPython.display import Image
from IPython.core.display import HTML

# %%
df = pd.read_csv('../data/images_info_table.csv')

# %%
plot_ft_many(df, 'tissue')

# %%
df['ft'] = np.where(df['tissue']=='Lung', 'Lung', 'Not_Lung')

# %%
plot_ft_many(df, 'ft')

# %% [markdown]
# ## First unbalanced model

# %%
Image(url= '../results/lung_ub_model/results/lung_ub_model_predictions_result.png')
# Out:
# <img src="../results/lung_ub_model/results/lung_ub_model_predictions_result.png"/>

# %% [markdown]
# ## Doc cat models

# %% [markdown]
# ### Balanced (1000 vs 1000)

# %%
Image(url= '../results/cat_dog_bl_model/results/cat_dog_bl_model_predictions_result.png')
# Out:
# <img src="../results/cat_dog_bl_model/results/cat_dog_bl_model_predictions_result.png"/>

# %% [markdown]
# ### Starting from our 4:1 proportion and balancing using augmentation

# %%
Image(url= '../results/cat_dog_agu_model/results/cat_dog_agu_model_predictions_result.png')
# Out:
# <img src="../results/cat_dog_agu_model/results/cat_dog_agu_model_predictions_result.png"/>

# %% [markdown]
# ## Balancing our dataset

# %%
Image(url= '../results/lung_model/results/lung_model_predictions_result.png')
# Out:
# <img src="../results/lung_model/results/lung_model_predictions_result.png"/>

# %% [markdown]
# ## Cell segmentation

# %%
Image(url= '../results/lung_out/results/lung_out_predictions_result.png')
# Out:
# <img src="../results/lung_out/results/lung_out_predictions_result.png"/>

# %%
Image(url= '../results/lung_over/results/lung_over_predictions_result.png')
# Out:
# <img src="../results/lung_over/results/lung_over_predictions_result.png"/>

# %%
Image(url= '../results/lung_flowi/results/lung_flowi_predictions_result.png')
# Out:
# <img src="../results/lung_flowi/results/lung_flowi_predictions_result.png"/>
