# %% [markdown]
# Notebook to generate tables to be used in the model pipeline

# %%
import pandas as pd
import numpy as np

from CMP_functions.preprocessing import *

# %%
table = '../data/images_info_table.csv'

ft = 'tissue'
split_on = 'Breast'

name = 'Breast'

# %%
df = pd.read_csv(table)

# %%
df
# Out:
#          im_id  master_id model_name        synonyms model_type  \
# 0    1877-8278       1877   SU-DHL-8             NaN  Cell Line
# 1    1476-8001       1476      SCC-4             NaN  Cell Line
# 2    1068-8758       1068     PCI-4B  PCI-04B;PCI-4M  Cell Line
# 3    2195-8403       2195      HuH-7          JTC-39  Cell Line
# 4          162        162        DOK             NaN  Cell Line
# ..         ...        ...        ...             ...        ...
# 731   706-9149        706   HO-1-N-1        Nakata-1  Cell Line
# 732        153        153  SK-MEL-31          AX-Mel  Cell Line
# 733  1875-8232       1875  NCI-H1048             NaN  Cell Line
# 734  2138-8023       2138   EC-GI-10             NaN  Cell Line
# 735  1747-8787       1747   STS-0421             NaN  Cell Line
#
#     growth_properties  doi  pmed  model_treatment model_comments  ...  \
# 0          Suspension  NaN   NaN              NaN            NaN  ...
# 1            Adherent  NaN   NaN              NaN            NaN  ...
# 2             Unknown  NaN   NaN              NaN            NaN  ...
# 3             Unknown  NaN   NaN              NaN            NaN  ...
# 4            Adherent  NaN   NaN              NaN            NaN  ...
# ..                ...  ...   ...              ...            ...  ...
# 731          Adherent  NaN   NaN              NaN            NaN  ...
# 732          Adherent  NaN   NaN              NaN            NaN  ...
# 733          Adherent  NaN   NaN              NaN            NaN  ...
# 734          Adherent  NaN   NaN              NaN            NaN  ...
# 735           Unknown  NaN   NaN              NaN            NaN  ...
#
#       ethnicity  smoking_status  model_relations_comment COSMIC_ID  \
# 0       Unknown         Unknown                      NaN   1331038
# 1       Unknown         Unknown                      NaN    910904
# 2       Unknown         Unknown                      NaN   1298531
# 3    East Asian         Unknown                      NaN    907071
# 4         White         Unknown                      NaN    910936
# ..          ...             ...                      ...       ...
# 731     Unknown         Unknown                      NaN    924111
# 732     Unknown         Unknown                      NaN    909727
# 733     Unknown         Unknown                      NaN    687995
# 734  East Asian         Unknown                      NaN    753555
# 735     Unknown         Unknown                      NaN   1299061
#
#        BROAD_ID                                    CCLE_ID       RRID  HCMI  \
# 0    ACH-000656  SUDHL8_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  CVCL_2207   NaN
# 1    ACH-000238             SCC4_UPPER_AERODIGESTIVE_TRACT  CVCL_1684   NaN
# 2    ACH-002297            PCI4B_UPPER_AERODIGESTIVE_TRACT  CVCL_C171   NaN
# 3    ACH-000480                                 HUH7_LIVER  CVCL_0336   NaN
# 4    ACH-002234              DOK_UPPER_AERODIGESTIVE_TRACT  CVCL_1180   NaN
# ..          ...                                        ...        ...   ...
# 731  ACH-002244            HO1N1_UPPER_AERODIGESTIVE_TRACT  CVCL_1284   NaN
# 732  ACH-000640                               SKMEL31_SKIN  CVCL_0600   NaN
# 733  ACH-000866                              NCIH1048_LUNG  CVCL_1453   NaN
# 734  ACH-000305                          ECGI10_OESOPHAGUS  CVCL_1187   NaN
# 735  ACH-002306                        STS0421_SOFT_TISSUE  CVCL_X508   NaN
#
#            suppliers       SIDM
# 0       DSMZ:ACC-573  SIDM00423
# 1      ATCC:CRL-1624  SIDM01081
# 2    Unknown:Unknown  SIDM00043
# 3      JCRB:JCRB0403  SIDM00585
# 4     ECACC:94122104  SIDM00540
# ..               ...        ...
# 731    JCRB:JCRB0831  SIDM00592
# 732      ATCC:HTB-73  SIDM01104
# 733    ATCC:CRL-5853  SIDM00654
# 734    RIKEN:RCB0774  SIDM00278
# 735  Unknown:Unknown  SIDM00041
#
# [736 rows x 52 columns]

# %%
df.columns
# Out:
# Index(['im_id', 'master_id', 'model_name', 'synonyms', 'model_type',
#        'growth_properties', 'doi', 'pmed', 'model_treatment', 'model_comments',
#        'msi_status', 'mutational_burden', 'ploidy', 'parent_id',
#        'mutation_data', 'methylation_data', 'expression_data', 'cnv_data',
#        'crispr_ko_data', 'fusion_data', 'drug_data', 'sample_id', 'tissue',
#        'tissue_status', 'cancer_type', 'cancer_type_detail',
#        'cancer_type_ncit_id', 'age_at_sampling', 'sampling_day',
#        'sampling_month', 'sampling_year', 'sample_treatment',
#        'sample_treatment_details', 'sample_site', 'tnm_t', 'tnm_n', 'tnm_m',
#        'tnm_integrated', 'tumour_grade', 'patient_id', 'species', 'gender',
#        'ethnicity', 'smoking_status', 'model_relations_comment', 'COSMIC_ID',
#        'BROAD_ID', 'CCLE_ID', 'RRID', 'HCMI', 'suppliers', 'SIDM', 'ft'],
#       dtype='object')

# %%
set(df[ft])
# Out:
# {'Adrenal Gland',
#  'Biliary Tract',
#  'Bladder',
#  'Bone',
#  'Breast',
#  'Central Nervous System',
#  'Cervix',
#  'Endometrium',
#  'Esophagus',
#  'Haematopoietic and Lymphoid',
#  'Head and Neck',
#  'Kidney',
#  'Large Intestine',
#  'Liver',
#  'Lung',
#  'Ovary',
#  'Pancreas',
#  'Peripheral Nervous System',
#  'Placenta',
#  'Prostate',
#  'Skin',
#  'Soft Tissue',
#  'Stomach',
#  'Testis',
#  'Thyroid',
#  'Uterus',
#  'Vulva'}

# %%
plot_ft_many(df, ft)

# %%
df['ft'] = np.where(df[ft]==split_on, split_on, 'Not_'+split_on)

# %%
df
# Out:
#          im_id  master_id model_name        synonyms model_type  \
# 0    1877-8278       1877   SU-DHL-8             NaN  Cell Line
# 1    1476-8001       1476      SCC-4             NaN  Cell Line
# 2    1068-8758       1068     PCI-4B  PCI-04B;PCI-4M  Cell Line
# 3    2195-8403       2195      HuH-7          JTC-39  Cell Line
# 4          162        162        DOK             NaN  Cell Line
# ..         ...        ...        ...             ...        ...
# 731   706-9149        706   HO-1-N-1        Nakata-1  Cell Line
# 732        153        153  SK-MEL-31          AX-Mel  Cell Line
# 733  1875-8232       1875  NCI-H1048             NaN  Cell Line
# 734  2138-8023       2138   EC-GI-10             NaN  Cell Line
# 735  1747-8787       1747   STS-0421             NaN  Cell Line
#
#     growth_properties  doi  pmed  model_treatment model_comments  ...  \
# 0          Suspension  NaN   NaN              NaN            NaN  ...
# 1            Adherent  NaN   NaN              NaN            NaN  ...
# 2             Unknown  NaN   NaN              NaN            NaN  ...
# 3             Unknown  NaN   NaN              NaN            NaN  ...
# 4            Adherent  NaN   NaN              NaN            NaN  ...
# ..                ...  ...   ...              ...            ...  ...
# 731          Adherent  NaN   NaN              NaN            NaN  ...
# 732          Adherent  NaN   NaN              NaN            NaN  ...
# 733          Adherent  NaN   NaN              NaN            NaN  ...
# 734          Adherent  NaN   NaN              NaN            NaN  ...
# 735           Unknown  NaN   NaN              NaN            NaN  ...
#
#     smoking_status  model_relations_comment  COSMIC_ID    BROAD_ID  \
# 0          Unknown                      NaN    1331038  ACH-000656
# 1          Unknown                      NaN     910904  ACH-000238
# 2          Unknown                      NaN    1298531  ACH-002297
# 3          Unknown                      NaN     907071  ACH-000480
# 4          Unknown                      NaN     910936  ACH-002234
# ..             ...                      ...        ...         ...
# 731        Unknown                      NaN     924111  ACH-002244
# 732        Unknown                      NaN     909727  ACH-000640
# 733        Unknown                      NaN     687995  ACH-000866
# 734        Unknown                      NaN     753555  ACH-000305
# 735        Unknown                      NaN    1299061  ACH-002306
#
#                                        CCLE_ID       RRID  HCMI  \
# 0    SUDHL8_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  CVCL_2207   NaN
# 1               SCC4_UPPER_AERODIGESTIVE_TRACT  CVCL_1684   NaN
# 2              PCI4B_UPPER_AERODIGESTIVE_TRACT  CVCL_C171   NaN
# 3                                   HUH7_LIVER  CVCL_0336   NaN
# 4                DOK_UPPER_AERODIGESTIVE_TRACT  CVCL_1180   NaN
# ..                                         ...        ...   ...
# 731            HO1N1_UPPER_AERODIGESTIVE_TRACT  CVCL_1284   NaN
# 732                               SKMEL31_SKIN  CVCL_0600   NaN
# 733                              NCIH1048_LUNG  CVCL_1453   NaN
# 734                          ECGI10_OESOPHAGUS  CVCL_1187   NaN
# 735                        STS0421_SOFT_TISSUE  CVCL_X508   NaN
#
#            suppliers       SIDM          ft
# 0       DSMZ:ACC-573  SIDM00423  Not_Breast
# 1      ATCC:CRL-1624  SIDM01081  Not_Breast
# 2    Unknown:Unknown  SIDM00043  Not_Breast
# 3      JCRB:JCRB0403  SIDM00585  Not_Breast
# 4     ECACC:94122104  SIDM00540  Not_Breast
# ..               ...        ...         ...
# 731    JCRB:JCRB0831  SIDM00592  Not_Breast
# 732      ATCC:HTB-73  SIDM01104  Not_Breast
# 733    ATCC:CRL-5853  SIDM00654  Not_Breast
# 734    RIKEN:RCB0774  SIDM00278  Not_Breast
# 735  Unknown:Unknown  SIDM00041  Not_Breast
#
# [736 rows x 53 columns]

# %%
plot_ft_many(df, 'ft')

# %%
new_df =  df[['im_id','ft']]

# %%
new_df
# Out:
#          im_id          ft
# 0    1877-8278  Not_Breast
# 1    1476-8001  Not_Breast
# 2    1068-8758  Not_Breast
# 3    2195-8403  Not_Breast
# 4          162  Not_Breast
# ..         ...         ...
# 731   706-9149  Not_Breast
# 732        153  Not_Breast
# 733  1875-8232  Not_Breast
# 734  2138-8023  Not_Breast
# 735  1747-8787  Not_Breast
#
# [736 rows x 2 columns]

# %%
new_df.to_csv(name+'.csv', index=False)

# %% [markdown]
# ## Extract cancer status

# %%
plot_ft_many(df, 'tissue_status')

# %%
tumor_df = df[df.tissue_status=="Tumour"]
metastasis_df = df[df.tissue_status=="Metastasis"]

# %%
status_df = pd.concat([tumor_df, metastasis_df])

# %%
set(status_df.tissue_status)
# Out:
# {'Metastasis', 'Tumour'}

# %%
status_df
# Out:
#          im_id  master_id model_name  synonyms model_type growth_properties  \
# 1    1476-8001       1476      SCC-4       NaN  Cell Line          Adherent
# 3    2195-8403       2195      HuH-7    JTC-39  Cell Line           Unknown
# 4          162        162        DOK       NaN  Cell Line          Adherent
# 5     924-8045        924     MOLP-8       NaN  Cell Line        Suspension
# 7         1145       1145     U-2-OS  U20-S;2T  Cell Line          Adherent
# ..         ...        ...        ...       ...        ...               ...
# 725   382-8402        382       TE-4       NaN  Cell Line          Adherent
# 728  1615-8947       1615   NCI-H345       NaN  Cell Line     Semi-Adherent
# 729  1251-8747       1251     NUGC-3       NaN  Cell Line           Unknown
# 733  1875-8232       1875  NCI-H1048       NaN  Cell Line          Adherent
# 734  2138-8023       2138   EC-GI-10       NaN  Cell Line          Adherent
#
#                     doi  pmed  model_treatment model_comments  ...  \
# 1                   NaN   NaN              NaN            NaN  ...
# 3                   NaN   NaN              NaN            NaN  ...
# 4                   NaN   NaN              NaN            NaN  ...
# 5                   NaN   NaN              NaN            NaN  ...
# 7                   NaN   NaN              NaN            NaN  ...
# ..                  ...   ...              ...            ...  ...
# 725                 NaN   NaN              NaN            NaN  ...
# 728                 NaN   NaN              NaN            NaN  ...
# 729  10.1007/BF02471470   NaN              NaN            NaN  ...
# 733                 NaN   NaN              NaN            NaN  ...
# 734                 NaN   NaN              NaN            NaN  ...
#
#     smoking_status  model_relations_comment  COSMIC_ID    BROAD_ID  \
# 1          Unknown                      NaN     910904  ACH-000238
# 3          Unknown                      NaN     907071  ACH-000480
# 4          Unknown                      NaN     910936  ACH-002234
# 5          Unknown                      NaN    1330950  ACH-000745
# 7          Unknown                      NaN     909776  ACH-000364
# ..             ...                      ...        ...         ...
# 725        Unknown                      NaN    1503371  ACH-000917
# 728        Unknown                      NaN     688021  ACH-001364
# 729        Unknown                      NaN     908455  ACH-000911
# 733        Unknown                      NaN     687995  ACH-000866
# 734        Unknown                      NaN     753555  ACH-000305
#
#                                       CCLE_ID       RRID  HCMI  \
# 1              SCC4_UPPER_AERODIGESTIVE_TRACT  CVCL_1684   NaN
# 3                                  HUH7_LIVER  CVCL_0336   NaN
# 4               DOK_UPPER_AERODIGESTIVE_TRACT  CVCL_1180   NaN
# 5    MOLP8_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  CVCL_2124   NaN
# 7                                   U2OS_BONE  CVCL_0042   NaN
# ..                                        ...        ...   ...
# 725                            TE4_OESOPHAGUS  CVCL_3337   NaN
# 728                              NCIH345_LUNG  CVCL_1558   NaN
# 729                             NUGC3_STOMACH  CVCL_1612   NaN
# 733                             NCIH1048_LUNG  CVCL_1453   NaN
# 734                         ECGI10_OESOPHAGUS  CVCL_1187   NaN
#
#           suppliers       SIDM                               ft
# 1     ATCC:CRL-1624  SIDM01081  Not_Haematopoietic and Lymphoid
# 3     JCRB:JCRB0403  SIDM00585  Not_Haematopoietic and Lymphoid
# 4    ECACC:94122104  SIDM00540  Not_Haematopoietic and Lymphoid
# 5      DSMZ:ACC-569  SIDM00434      Haematopoietic and Lymphoid
# 7       ATCC:HTB-96  SIDM01191  Not_Haematopoietic and Lymphoid
# ..              ...        ...                              ...
# 725   RIKEN:RCB2097  SIDM00250  Not_Haematopoietic and Lymphoid
# 728    ATCC:HTB-180  SIDM00719  Not_Haematopoietic and Lymphoid
# 729   JCRB:JCRB0822  SIDM00572  Not_Haematopoietic and Lymphoid
# 733   ATCC:CRL-5853  SIDM00654  Not_Haematopoietic and Lymphoid
# 734   RIKEN:RCB0774  SIDM00278  Not_Haematopoietic and Lymphoid
#
# [671 rows x 53 columns]

# %%
plot_ft_many(status_df, 'tissue_status')

# %%
status_df['ft'] = np.where(status_df['tissue_status']=="Tumour", "Tumour", "Metastasis")

# %%
status_df
# Out:
#          im_id  master_id model_name  synonyms model_type growth_properties  \
# 1    1476-8001       1476      SCC-4       NaN  Cell Line          Adherent
# 3    2195-8403       2195      HuH-7    JTC-39  Cell Line           Unknown
# 4          162        162        DOK       NaN  Cell Line          Adherent
# 5     924-8045        924     MOLP-8       NaN  Cell Line        Suspension
# 7         1145       1145     U-2-OS  U20-S;2T  Cell Line          Adherent
# ..         ...        ...        ...       ...        ...               ...
# 725   382-8402        382       TE-4       NaN  Cell Line          Adherent
# 728  1615-8947       1615   NCI-H345       NaN  Cell Line     Semi-Adherent
# 729  1251-8747       1251     NUGC-3       NaN  Cell Line           Unknown
# 733  1875-8232       1875  NCI-H1048       NaN  Cell Line          Adherent
# 734  2138-8023       2138   EC-GI-10       NaN  Cell Line          Adherent
#
#                     doi  pmed  model_treatment model_comments  ...  \
# 1                   NaN   NaN              NaN            NaN  ...
# 3                   NaN   NaN              NaN            NaN  ...
# 4                   NaN   NaN              NaN            NaN  ...
# 5                   NaN   NaN              NaN            NaN  ...
# 7                   NaN   NaN              NaN            NaN  ...
# ..                  ...   ...              ...            ...  ...
# 725                 NaN   NaN              NaN            NaN  ...
# 728                 NaN   NaN              NaN            NaN  ...
# 729  10.1007/BF02471470   NaN              NaN            NaN  ...
# 733                 NaN   NaN              NaN            NaN  ...
# 734                 NaN   NaN              NaN            NaN  ...
#
#     smoking_status  model_relations_comment  COSMIC_ID    BROAD_ID  \
# 1          Unknown                      NaN     910904  ACH-000238
# 3          Unknown                      NaN     907071  ACH-000480
# 4          Unknown                      NaN     910936  ACH-002234
# 5          Unknown                      NaN    1330950  ACH-000745
# 7          Unknown                      NaN     909776  ACH-000364
# ..             ...                      ...        ...         ...
# 725        Unknown                      NaN    1503371  ACH-000917
# 728        Unknown                      NaN     688021  ACH-001364
# 729        Unknown                      NaN     908455  ACH-000911
# 733        Unknown                      NaN     687995  ACH-000866
# 734        Unknown                      NaN     753555  ACH-000305
#
#                                       CCLE_ID       RRID  HCMI  \
# 1              SCC4_UPPER_AERODIGESTIVE_TRACT  CVCL_1684   NaN
# 3                                  HUH7_LIVER  CVCL_0336   NaN
# 4               DOK_UPPER_AERODIGESTIVE_TRACT  CVCL_1180   NaN
# 5    MOLP8_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  CVCL_2124   NaN
# 7                                   U2OS_BONE  CVCL_0042   NaN
# ..                                        ...        ...   ...
# 725                            TE4_OESOPHAGUS  CVCL_3337   NaN
# 728                              NCIH345_LUNG  CVCL_1558   NaN
# 729                             NUGC3_STOMACH  CVCL_1612   NaN
# 733                             NCIH1048_LUNG  CVCL_1453   NaN
# 734                         ECGI10_OESOPHAGUS  CVCL_1187   NaN
#
#           suppliers       SIDM          ft
# 1     ATCC:CRL-1624  SIDM01081      Tumour
# 3     JCRB:JCRB0403  SIDM00585      Tumour
# 4    ECACC:94122104  SIDM00540      Tumour
# 5      DSMZ:ACC-569  SIDM00434      Tumour
# 7       ATCC:HTB-96  SIDM01191      Tumour
# ..              ...        ...         ...
# 725   RIKEN:RCB2097  SIDM00250  Metastasis
# 728    ATCC:HTB-180  SIDM00719  Metastasis
# 729   JCRB:JCRB0822  SIDM00572  Metastasis
# 733   ATCC:CRL-5853  SIDM00654  Metastasis
# 734   RIKEN:RCB0774  SIDM00278  Metastasis
#
# [671 rows x 53 columns]

# %%
status_for_pip = status_df[['im_id','ft']]

# %%
status_for_pip
# Out:
#          im_id          ft
# 1    1476-8001      Tumour
# 3    2195-8403      Tumour
# 4          162      Tumour
# 5     924-8045      Tumour
# 7         1145      Tumour
# ..         ...         ...
# 725   382-8402  Metastasis
# 728  1615-8947  Metastasis
# 729  1251-8747  Metastasis
# 733  1875-8232  Metastasis
# 734  2138-8023  Metastasis
#
# [671 rows x 2 columns]

# %%
status_for_pip.to_csv('status_table.csv', index=False)
